# %% [markdown]
# # Advanced Applications of Mutate
#
# ## Map and apply

# %%
import pandas as pd
from dfply import *
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ## Hiding stack traceback
#
# We hide the exception traceback for didactic reasons (code source: [see this post](https://stackoverflow.com/questions/46222753/how-do-i-suppress-tracebacks-in-jupyter)).  Don't run this cell if you want to see a full traceback.

# %%
import sys
ipython = get_ipython()

def hide_traceback(exc_tuple=None, filename=None, tb_offset=None,
                   exception_only=False, running_compiled_code=False):
    etype, value, tb = sys.exc_info()
    return ipython._showtraceback(etype, value, ipython.InteractiveTB.get_exception_only(etype, value))

ipython.showtraceback = hide_traceback

# %% [markdown]
# ## Data set
#
# We will be using two of the data sets provided by the Museam of Modern Art (MoMA) in this lecture.  Make sure that you have downloaded each repository.  [Download Instructions](./get_MOMA_data.ipynb)

# %% [markdown]
# #### MoMA Artists

# %%
artists = pd.read_csv("./data/Artists.csv")
artists.head(2)
# Out:
#    ConstituentID     DisplayName            ArtistBio Nationality Gender  \
# 0              1  Robert Arneson  American, 1930–1992    American   Male
# 1              2  Doroteo Arnaiz   Spanish, born 1936     Spanish   Male
#
#    BeginDate  EndDate Wiki QID  ULAN
# 0       1930     1992      NaN   NaN
# 1       1936        0      NaN   NaN

# %% [markdown]
# # Transforming columns with the `map` and `apply` methods
#
# Next, we will take a look at two useful `pandas Series` methods that allow us to apply very general transformations: `map` and `apply`.

# %% [markdown]
# ## Transforming a column with `map`
#
# `df.col.map` can be used to
#
# * Apply a translation `dict`
# * Apply a function
# * Apply a `pd.Series`

# %%
artists.Gender.value_counts()
# Out:
# Male          9762
# Female        2300
# male            15
# Non-Binary       2
# Non-binary       1
# female           1
# Name: Gender, dtype: int64

# %% [markdown]
# #### `map`ping a translation `dict`

# %%
new_gender = {'Male':'m', 'Female':'f', 'male':'m', 'female':'f', 'Non-Binary':'nb', 'Non-binary':'nb'}
(artists
 >> select(X.Gender)
 >> mutate(new_gender = X.Gender.map(new_gender))
 >> head(9)
)
# Out:
#    Gender new_gender
# 0    Male          m
# 1    Male          m
# 2    Male          m
# 3    Male          m
# 4    Male          m
# 5    Male          m
# 6    Male          m
# 7    Male          m
# 8  Female          f

# %% [markdown]
# #### Setting a default with `collections.defaultdict`

# %%
from collections import defaultdict

from_america = defaultdict(lambda: 'Not America')
from_america.update({'American':'America'})

# %% [markdown]
# #### Applying the `defaultdict`

# %%
(artists
 >> select(X.Nationality)
 >> mutate(from_america = X.Nationality.map(from_america))
 >> head(3)
)
# Out:
#   Nationality from_america
# 0    American      America
# 1     Spanish  Not America
# 2    American      America

# %% [markdown]
# #### `map`ping a simple function

# %%
(artists
 >> select(X.Nationality)
 >> mutate(from_USA = X.Nationality.map(lambda n: 'USA' if n == 'American' else 'Other'))
 >> head(3)
)
# Out:
#   Nationality from_USA
# 0    American      USA
# 1     Spanish    Other
# 2    American      USA

# %% [markdown]
# ## Be sure to `apply` yourself!
#
# * `df.col.apply` is used to apply any function to a column.
#     * Including positional and keyword arguments
# * Could literally be used to perform *any* mutation

# %% [markdown]
# #### Applying a unary function

# %%
century = lambda year_string: (int(year_string)//100)*100

(artists
 >> select(X.BeginDate)
 >> mutate(century_of_birth = X.BeginDate.apply(century))
 >> head(3)
)
# Out:
#    BeginDate  century_of_birth
# 0       1930              1900
# 1       1936              1900
# 2       1941              1900

# %% [markdown]
# ## Using anonymous functions
#
# * There is no need to name a `lambda`
# * An embedded `lambda` is called an **anonymous function**

# %%
(artists
 >> select(X.EndDate)
 >> mutate(new_end_date = (X.EndDate
                           .apply(lambda y: y if int(y) > 0 else np.nan)
                           .astype('Int64')))
 >> head(2)
)
# Out:
#    EndDate  new_end_date
# 0     1992          1992
# 1        0          <NA>

# %% [markdown]
# ## `apply` or `map`
#
# * Use `map` for simple functions
# * Use `apply` when adding additional arguments

# %% [markdown]
# #### MoMA Artwork

# %%
from more_dfply import fix_names

artwork = (pd.read_csv("./data/Artworks.csv")
           >> fix_names
           >> mutate(id = X.index + 1)
          )
artwork.head(2)
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
#
#                      Artist ConstituentID              ArtistBio Nationality  \
# 0               Otto Wagner          6210  (Austrian, 1841–1918)  (Austrian)
# 1  Christian de Portzamparc          7470    (French, born 1944)    (French)
#
#   BeginDate EndDate  Gender  Date  \
# 0    (1841)  (1918)  (Male)  1896
# 1    (1944)     (0)  (Male)  1987
#
#                                           Medium  ... Circumference_cm  \
# 0  Ink and cut-and-pasted painted pages on paper  ...              NaN
# 1              Paint and colored pencil on print  ...              NaN
#
#   Depth_cm Diameter_cm Height_cm Length_cm Weight_kg  Width_cm  \
# 0      NaN         NaN   48.6000       NaN       NaN  168.9000
# 1      NaN         NaN   40.6401       NaN       NaN   29.8451
#
#    Seat_Height_cm Duration_sec id
# 0             NaN          NaN  1
# 1             NaN          NaN  2
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Setting a positional argument
#
# We want to apply `round(val, 1)`

# %%
(artwork
 >> select(X.Height_cm)
 >> mutate(rounded_height = X.Height_cm.apply(round, args=(1,)))
 >> head(3)
)
# Out:
#    Height_cm  rounded_height
# 0    48.6000            48.6
# 1    40.6401            40.6
# 2    34.3000            34.3

# %% [markdown]
# #### Setting a keyword argument
#
# We want to apply `logp1(val, base=n)`

# %%
from math import log, e

log1p = lambda num, base=e: log(num + 1, base)
(artwork
 >> select(X.Height_cm)
 >> mutate(log10_plus_1 = X.Height_cm.apply(log1p, base = 10),
           log2_plus_1 = X.Height_cm.apply(log1p, base = 2),
           ln_plus_1 = X.Height_cm.apply(log1p, base = e))
 >> head(3)
)
# Out:
#    Height_cm  log10_plus_1  log2_plus_1  ln_plus_1
# 0    48.6000      1.695482     5.632268   3.903991
# 1    40.6401      1.619512     5.379902   3.729064
# 2    34.3000      1.547775     5.141596   3.563883

# %% [markdown]
# ## <font color="red"> Exercise 2 </font>
#
# An **Indicator column** for a category contains 1 for the rows that match that label and 0 otherwise.  The `exhibitions` dataframe.  Complete the following tasks.
#
# 1. Use `exhibitions.ExhibitionRole.unique()` to get a list of unique columns.
# 2. Use `mutate` and `map` with `defaultdict` to create an indicator column for each category (ignore missing rows).
# 3. Comment on the quality of your solution, especially in light of the [DRY principle](https://en.wikipedia.org/wiki/Don%27t_repeat_yourself)

# %% [markdown]
# #### MoMA Exhibitions

# %%
dat_cols = ['ExhibitionBeginDate', 'ExhibitionEndDate', 'ConstituentBeginDate' ,'ConstituentEndDate']
exhibitions = pd.read_csv('./data/MoMAExhibitions1929to1989.csv', 
                          encoding="ISO-8859-1",
                          parse_dates=dat_cols)
exhibitions.head(50)
# Out:
#     ExhibitionID ExhibitionNumber                     ExhibitionTitle  \
# 0         2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 1         2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 2         2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 3         2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 4         2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 5         2724.0                2    Paintings by 19 Living Americans
# 6         2724.0                2    Paintings by 19 Living Americans
# 7         2724.0                2    Paintings by 19 Living Americans
# 8         2724.0                2    Paintings by 19 Living Americans
# 9         2724.0                2    Paintings by 19 Living Americans
# 10        2724.0                2    Paintings by 19 Living Americans
# 11        2724.0                2    Paintings by 19 Living Americans
# 12        2724.0                2    Paintings by 19 Living Americans
# 13        2724.0                2    Paintings by 19 Living Americans
# 14        2724.0                2    Paintings by 19 Living Americans
# 15        2724.0                2    Paintings by 19 Living Americans
# 16        2724.0                2    Paintings by 19 Living Americans
# 17        2724.0                2    Paintings by 19 Living Americans
# 18        2724.0                2    Paintings by 19 Living Americans
# 19        2724.0                2    Paintings by 19 Living Americans
# 20        2724.0                2    Paintings by 19 Living Americans
# 21        2724.0                2    Paintings by 19 Living Americans
# 22        2724.0                2    Paintings by 19 Living Americans
# 23        2724.0                2    Paintings by 19 Living Americans
# 24        2942.0                3                   Painting in Paris
# 25        2942.0                3                   Painting in Paris
# 26        2942.0                3                   Painting in Paris
# 27        2942.0                3                   Painting in Paris
# 28        2942.0                3                   Painting in Paris
# 29        2942.0                3                   Painting in Paris
# 30        2942.0                3                   Painting in Paris
# 31        2942.0                3                   Painting in Paris
# 32        2942.0                3                   Painting in Paris
# 33        2942.0                3                   Painting in Paris
# 34        2942.0                3                   Painting in Paris
# 35        2942.0                3                   Painting in Paris
# 36        2942.0                3                   Painting in Paris
# 37        2942.0                3                   Painting in Paris
# 38        2942.0                3                   Painting in Paris
# 39        2942.0                3                   Painting in Paris
# 40        2942.0                3                   Painting in Paris
# 41        2942.0                3                   Painting in Paris
# 42        2942.0                3                   Painting in Paris
# 43        2942.0                3                   Painting in Paris
# 44        2942.0                3                   Painting in Paris
# 45        2942.0                3                   Painting in Paris
# 46        2942.0                3                   Painting in Paris
# 47        2942.0                3                   Painting in Paris
# 48        2942.0                3                   Painting in Paris
# 49        2942.0                3                   Painting in Paris
#
#                           ExhibitionCitationDate ExhibitionBeginDate  \
# 0    [MoMA Exh. #1, November 7-December 7, 1929]          1929-11-07
# 1    [MoMA Exh. #1, November 7-December 7, 1929]          1929-11-07
# 2    [MoMA Exh. #1, November 7-December 7, 1929]          1929-11-07
# 3    [MoMA Exh. #1, November 7-December 7, 1929]          1929-11-07
# 4    [MoMA Exh. #1, November 7-December 7, 1929]          1929-11-07
# 5   [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 6   [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 7   [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 8   [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 9   [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 10  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 11  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 12  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 13  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 14  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 15  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 16  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 17  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 18  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 19  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 20  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 21  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 22  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 23  [MoMA Exh. #2, December 12-January 12, 1930]          1929-12-12
# 24      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 25      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 26      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 27      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 28      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 29      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 30      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 31      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 32      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 33      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 34      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 35      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 36      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 37      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 38      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 39      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 40      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 41      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 42      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 43      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 44      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 45      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 46      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 47      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 48      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
# 49      [MoMA Exh. #3, January 18-March 2, 1930]          1930-01-19
#
#    ExhibitionEndDate  ExhibitionSortOrder                       ExhibitionURL  \
# 0         1929-12-07                  1.0  moma.org/calendar/exhibitions/1767
# 1         1929-12-07                  1.0  moma.org/calendar/exhibitions/1767
# 2         1929-12-07                  1.0  moma.org/calendar/exhibitions/1767
# 3         1929-12-07                  1.0  moma.org/calendar/exhibitions/1767
# 4         1929-12-07                  1.0  moma.org/calendar/exhibitions/1767
# 5         1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 6         1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 7         1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 8         1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 9         1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 10        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 11        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 12        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 13        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 14        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 15        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 16        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 17        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 18        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 19        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 20        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 21        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 22        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 23        1930-01-12                  2.0  moma.org/calendar/exhibitions/1912
# 24        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 25        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 26        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 27        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 28        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 29        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 30        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 31        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 32        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 33        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 34        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 35        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 36        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 37        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 38        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 39        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 40        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 41        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 42        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 43        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 44        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 45        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 46        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 47        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 48        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
# 49        1930-03-02                  3.0  moma.org/calendar/exhibitions/2024
#
#    ExhibitionRole ExhibitionRoleinPressRelease  ...  Institution Nationality  \
# 0         Curator                     Director  ...          NaN    American
# 1          Artist                       Artist  ...          NaN      French
# 2          Artist                       Artist  ...          NaN      French
# 3          Artist                       Artist  ...          NaN       Dutch
# 4          Artist                       Artist  ...          NaN      French
# 5          Artist                       Artist  ...          NaN    American
# 6          Artist                       Artist  ...          NaN    American
# 7          Artist                       Artist  ...          NaN    American
# 8          Artist                       Artist  ...          NaN    American
# 9          Artist                       Artist  ...          NaN    American
# 10         Artist                       Artist  ...          NaN    American
# 11         Artist                       Artist  ...          NaN    American
# 12         Artist                       Artist  ...          NaN    American
# 13         Artist                       Artist  ...          NaN    American
# 14         Artist                       Artist  ...          NaN    American
# 15         Artist                       Artist  ...          NaN    American
# 16         Artist                       Artist  ...          NaN    American
# 17         Artist                       Artist  ...          NaN    American
# 18         Artist                       Artist  ...          NaN    American
# 19         Artist                       Artist  ...          NaN    American
# 20         Artist                       Artist  ...          NaN    American
# 21         Artist                       Artist  ...          NaN    American
# 22         Artist                       Artist  ...          NaN    American
# 23         Artist                       Artist  ...          NaN    American
# 24         Artist                       Artist  ...          NaN      French
# 25         Artist                       Artist  ...          NaN      French
# 26         Artist                       Artist  ...          NaN      French
# 27         Artist                       Artist  ...          NaN     Italian
# 28         Artist                       Artist  ...          NaN      French
# 29         Artist                       Artist  ...          NaN      French
# 30         Artist                       Artist  ...          NaN         NaN
# 31         Artist                       Artist  ...          NaN      French
# 32         Artist                       Artist  ...          NaN      French
# 33         Artist                       Artist  ...          NaN      French
# 34         Artist                       Artist  ...          NaN      French
# 35         Artist                       Artist  ...          NaN      French
# 36         Artist                       Artist  ...          NaN      French
# 37         Artist                       Artist  ...          NaN      French
# 38         Artist                       Artist  ...          NaN      French
# 39         Artist                       Artist  ...          NaN      French
# 40         Artist                       Artist  ...          NaN      French
# 41         Artist                       Artist  ...          NaN     Spanish
# 42         Artist                       Artist  ...          NaN     Spanish
# 43         Artist                       Artist  ...          NaN      French
# 44         Artist                       Artist  ...          NaN      French
# 45         Artist                       Artist  ...          NaN      French
# 46         Artist                       Artist  ...          NaN      French
# 47         Artist                       Artist  ...          NaN      French
# 48         Artist                       Artist  ...          NaN      French
# 49         Artist                       Artist  ...          NaN      French
#
#    ConstituentBeginDate ConstituentEndDate  \
# 0                  1902               1981
# 1                  1839               1906
# 2                  1848               1903
# 3                  1853               1890
# 4                  1859               1891
# 5                  1893               1967
# 6                  1883               1935
# 7                  1889               1930
# 8                  1871               1956
# 9                  1868               1933
# 10                 1882               1967
# 11                 1886               1952
# 12                 1882               1971
# 13                 1877               1949
# 14                 1889               1953
# 15                 1873               1939
# 16                 1870               1953
# 17                 1876               1952
# 18                 1887               1986
# 19                 1885               1930
# 20                 1871               1951
# 21                 1883               1962
# 22                 1877               1957
# 23                 1881               1961
# 24                 1867               1947
# 25                 1882               1963
# 26                 1887               1985
# 27                 1888               1978
# 28                 1885               1941
# 29                 1880               1954
# 30                  NaN                NaN
# 31                 1877               1953
# 32                 1898               1964
# 33                 1852               1931
# 34                 1879               1949
# 35                 1892               1971
# 36                 1891               1953
# 37                 1883               1956
# 38                 1881               1955
# 39                 1892               1966
# 40                 1869               1954
# 41                 1893               1983
# 42                 1881               1973
# 43                 1871               1958
# 44                 1884               1974
# 45                 1893               1943
# 46                 1879               1968
# 47                 1883               1955
# 48                 1876               1958
# 49                 1868               1940
#
#                              ArtistBio  Gender       VIAFID WikidataID  \
# 0                  American, 19021981    Male  109252853.0    Q711362
# 1                    French, 18391906    Male   39374836.0     Q35548
# 2                    French, 18481903    Male   27064953.0     Q37693
# 3                     Dutch, 18531890    Male    9854560.0      Q5582
# 4                    French, 18591891    Male   24608076.0     Q34013
# 5                  American, 18931967    Male   34533792.0   Q3349279
# 6                  American, 18831935    Male   29542716.0    Q380494
# 7                  American, 18891930    Male   25491785.0   Q3402687
# 8                  American, 18711956    Male   49225327.0    Q158255
# 9                  American, 18681933    Male   61822646.0  Q19795994
# 10                 American, 18821967    Male   32101533.0    Q203401
# 11                 American, 18861952    Male   36883547.0    Q822507
# 12                 American, 18821971    Male   24685053.0    Q114405
# 13                 American, 18771949    Male   33084024.0    Q118798
# 14                 American, 18891953    Male   13102247.0   Q3571991
# 15                 American, 18731939    Male    3356751.0   Q1185478
# 16                 American, 18701953    Male   74649315.0    Q666171
# 17                 American, 18761952    Male   23718655.0   Q3195174
# 18                 American, 18871986  Female   32021794.0     Q46408
# 19  American, born Bulgaria. 18851930    Male   97262322.0    Q469063
# 20                 American, 18711951    Male  100215096.0    Q861756
# 21                 American, 18831962    Male   88623908.0  Q15503771
# 22    American, born Latvia. 18771957    Male   95844995.0   Q3852444
# 23    American, born Russia. 18811961    Male   41883358.0    Q535334
# 24                   French, 18671947    Male   66499977.0     Q26408
# 25                   French, 18821963    Male    9867924.0    Q153793
# 26     French, born Belarus. 18871985    Male  103953801.0     Q93284
# 27     Italian, born Greece. 18881978    Male  104172730.0    Q156622
# 28                   French, 18851941    Male   68979341.0     Q33978
# 29                   French, 18801954    Male    2469239.0    Q156272
# 30                                 NaN     NaN          NaN        NaN
# 31                   French, 18771953    Male   56661160.0     Q45205
# 32                   French, 18981964    Male   66467022.0    Q537838
# 33                   French, 18521931    Male   44307245.0    Q719614
# 34                   French, 18791949    Male    2603019.0    Q708482
# 35                   French, 18921971    Male   19678327.0    Q690155
# 36      French, born Poland. 18911953    Male   19687435.0    Q281812
# 37                   French, 18831956  Female  122131844.0    Q233088
# 38                   French, 18811955    Male   34459370.0    Q157183
# 39                   French, 18921966    Male   31999657.0    Q468453
# 40                   French, 18691954    Male   42630086.0      Q5589
# 41                  Spanish, 18931983    Male    9850739.0    Q152384
# 42                  Spanish, 18811973    Male      15873.0      Q5593
# 43                   French, 18711958    Male      16857.0    Q156128
# 44                   French, 18841974    Male   59081879.0    Q518406
# 45                   French, 18931943    Male   18015110.0    Q160141
# 46                   French, 18791968    Male   17229932.0    Q734172
# 47                   French, 18831955    Male   39385919.0    Q108301
# 48                   French, 18761958    Male   76346120.0    Q241098
# 49                   French, 18681940    Male   17397031.0    Q239394
#
#          ULANID          ConstituentURL
# 0   500241556.0   moma.org/artists/9168
# 1   500004793.0   moma.org/artists/1053
# 2   500011421.0   moma.org/artists/2098
# 3   500115588.0   moma.org/artists/2206
# 4   500008873.0   moma.org/artists/5358
# 5   500015189.0    moma.org/artists/870
# 6   500004441.0   moma.org/artists/1490
# 7   500124280.0   moma.org/artists/1537
# 8   500115308.0   moma.org/artists/1832
# 9   500027420.0   moma.org/artists/2519
# 10  500031212.0   moma.org/artists/2726
# 11  500018085.0   moma.org/artists/3001
# 12  500006820.0   moma.org/artists/3065
# 13  500012372.0   moma.org/artists/3288
# 14  500023210.0   moma.org/artists/3296
# 15  500026852.0  moma.org/artists/61685
# 16  500115368.0   moma.org/artists/3770
# 17  500025218.0   moma.org/artists/3985
# 18  500018666.0   moma.org/artists/4360
# 19  500028526.0   moma.org/artists/4514
# 20  500014645.0   moma.org/artists/5471
# 21  500003881.0   moma.org/artists/5559
# 22  500026464.0   moma.org/artists/5654
# 23  500029261.0   moma.org/artists/6275
# 24  500115555.0    moma.org/artists/665
# 25  500025200.0    moma.org/artists/744
# 26  500115354.0   moma.org/artists/1055
# 27  500032635.0   moma.org/artists/1106
# 28  500023463.0   moma.org/artists/1479
# 29  500004535.0   moma.org/artists/1500
# 30          NaN  moma.org/artists/61686
# 31  500024166.0   moma.org/artists/1646
# 32  500002013.0   moma.org/artists/1815
# 33  500115211.0   moma.org/artists/1935
# 34  500031339.0   moma.org/artists/2012
# 35  500009137.0   moma.org/artists/2356
# 36  500027290.0  moma.org/artists/22445
# 37  500011424.0   moma.org/artists/3408
# 38  500027374.0   moma.org/artists/6624
# 39  500014846.0   moma.org/artists/3641
# 40  500017300.0   moma.org/artists/3832
# 41  500014094.0   moma.org/artists/4016
# 42  500009666.0   moma.org/artists/4609
# 43  500024798.0   moma.org/artists/5053
# 44  500024152.0   moma.org/artists/5318
# 45  500004801.0   moma.org/artists/5543
# 46  500008491.0   moma.org/artists/5735
# 47  500008404.0   moma.org/artists/6046
# 48  500008582.0   moma.org/artists/6177
# 49  500014954.0   moma.org/artists/6194
#
# [50 rows x 28 columns]

# %%
# Your code here
exhibitions.ExhibitionRole.unique()
# Out:
# array(['Curator', 'Artist', nan, 'Arranger', 'Installer',
#        'Competition Judge', 'Designer', 'Preparer'], dtype=object)

# %%
exhibitions.ExhibitionRole.value_counts()
# Out:
# Artist               32537
# Curator               1495
# Installer              150
# Competition Judge      132
# Designer                66
# Arranger                31
# Preparer                13
# Name: ExhibitionRole, dtype: int64

# %%
from collections import defaultdict

is_artist = defaultdict(lambda: '0')
is_artist.update({'Artist':'1'})

# %%
(exhibitions
 >> select(X.ExhibitionRole)
 >> mutate(new_ExhibitionRole = X.ExhibitionRole.map(is_artist))
 >> head())
# Out:
#   ExhibitionRole new_ExhibitionRole
# 0        Curator                  0
# 1         Artist                  1
# 2         Artist                  1
# 3         Artist                  1
# 4         Artist                  1

# %% [markdown]
# > I guess the quality of this solution somewhat abides by the DRY principle. One of DRY's successful implementation would have elements that are logically related all change predictably and uniformly, and are thus kept in sync. In the solution above, if you change the defaultdict to a different value, it the new_ExhibitionRole column would change all rows that currently have 0 in them altogether.
